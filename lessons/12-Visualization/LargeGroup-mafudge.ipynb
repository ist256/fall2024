# %% [markdown]
# # Code Samples From Large Group
#
# Place your notes and code samples from large group here.

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
tips['count'] = 1

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  count
# 0         16.99  1.01  Female     No   Sun  Dinner     2      1
# 1         10.34  1.66    Male     No   Sun  Dinner     3      1
# 2         21.01  3.50    Male     No   Sun  Dinner     3      1
# 3         23.68  3.31    Male     No   Sun  Dinner     2      1
# 4         24.59  3.61  Female     No   Sun  Dinner     4      1
# ..          ...   ...     ...    ...   ...     ...   ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3      1
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2      1
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2      1
# 242       17.82  1.75    Male     No   Sat  Dinner     2      1
# 243       18.78  3.00  Female     No  Thur  Dinner     2      1
#
# [244 rows x 8 columns]

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size', 'count'], dtype='object')

# %%
sns.barplot(data=tips, x="sex", y="count", estimator="sum")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size', 'count'], dtype='object')

# %%
# total tips by sex
sns.barplot(data=tips, x="sex", y="tip", estimator="mean", errorbar=None)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size', 'count'], dtype='object')

# %%
sns.barplot(data=tips, x="size", y="total_bill", estimator="mean", errorbar=None)
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size', 'count'], dtype='object')

# %%
#total bill by part size and by time of day lunch / dinner

sns.barplot(data=tips, x="size", y="total_bill", estimator="mean", errorbar=None, hue="time")
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
#total bill by part size and by time of day lunch / dinner

sns.lineplot(data=tips, x="size", y="total_bill", estimator="mean", errorbar=None, hue="time")
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
#total bill by part size and by time of day lunch / dinner

sns.lineplot(data=tips, x="size", y="total_bill", estimator="mean", hue="time")
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size', 'count'], dtype='object')

# %%
# DO NOT DO THIS --- WHY?
# can't read x axis
sns.barplot(data=tips, x="total_bill", y="tip", estimator="mean", errorbar=None)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# DO NOT DO THIS --- WHY?
# wrong plot
sns.lineplot(data=tips, x="total_bill", y="tip", estimator="mean", errorbar=None)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#we want a scatter because X and Y are both continuous numbers
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# this will add a best fit line ... regression
sns.lmplot(data=tips, x="total_bill", y="tip")

# %%
# this will add a best fit line ... regression
# total_bill vs tip by sex
sns.lmplot(data=tips, x="total_bill", y="tip", hue="sex")

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size', 'count'], dtype='object')

# %%
# this will add a best fit line ... regression
# total_bill vs tip by sex
sns.lmplot(data=tips, x="total_bill", y="tip", hue="time")

# %%
# this will add a best fit line ... regression
# total_bill vs tip by smoker
sns.lmplot(data=tips, x="total_bill", y="tip", hue="smoker")

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size', 'count'], dtype='object')

# %%
# this will add a best fit line ... regression
# total_bill vs tip by day
sns.lmplot(data=tips, x="total_bill", y="tip", hue="day")

# %%
tips['sex'].unique()
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Male', 'Female']

# %%
tips['smoker'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']

# %%
def concat(a,b):
    return str(a) + "-" + str(b)

#axis=1 executes by row
# lambda means run in-line 
tips['sex-smoker'] = tips.apply(lambda row: concat(row['sex'], row['smoker']), axis=1)

# %%
tips['sex-smoker'].unique()
# Out:
# array(['Female-No', 'Male-No', 'Male-Yes', 'Female-Yes'], dtype=object)

# %%
# this will add a best fit line ... regression
# total_bill vs tip by day
sns.lmplot(data=tips, x="total_bill", y="tip", hue="sex-smoker")

# %%
import folium

# %%
mymap = folium.Map()
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
mymap = folium.Map(location=(25.7617,-80.1918), zoom_start=10)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
su_map = folium.Map(location=(43.0387, -76.1337), zoom_start=20)
su_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd
classesdf = pd.read_csv("https://raw.githubusercontent.com/mafudge/datasets/master/delimited/class-schedule.csv")
classesdf
# Out:
#    Course   Day     Time Building     Room       Lat       Lon
# 0  IST256     M   3:45pm      HBC  Gifford  43.03819 -76.13413
# 1  MAT221  TuTh  12:45pm    Bowne      104  43.03674 -76.13320
# 2  WRT206    MW   9:20am   Crouse      111  43.03852 -76.13676
# 3  COM222  TuTh   9:20am    NH II      232  43.04020 -76.13521
# 4  IST343    MW   2:15pm    Hinds      243  43.03834 -76.13364

# %%
folium.Marker(location=(43.0387, -76.1337), popup="hi", tooltip="low").add_to(su_map)

# %%
su_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for i, row in classesdf.iterrows():
    loc = (row['Lat'], row['Lon'])
    folium.Marker(location=loc, popup=row['Course']).add_to(su_map)

# %%
classesdf.columns
# Out:
# Index(['Course', 'Day', 'Time', 'Building', 'Room', 'Lat', 'Lon'], dtype='object')

# %%
su_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
